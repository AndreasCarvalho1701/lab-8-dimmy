# %% [markdown]
# # Labdummy DPO no Google Colab
#
# Este notebook executa o fluxo minimo do laboratorio usando os scripts do repositorio. O Colab e o ambiente recomendado para o treino, especialmente em maquinas locais simples.

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Opcional: montar Google Drive
#
# Descomente a celula abaixo se quiser salvar checkpoints e resultados no seu Drive.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Treinamento DPO

# %%
# !python train_dpo.py --model-name sshleifer/tiny-gpt2 --dataset-path data/hhh_preferences.jsonl --output-dir outputs/dpo-model --beta 0.1 --num-train-epochs 1

# %% [markdown]
# ## Validacao com prompt malicioso fixo

# %%
# !python test_model.py --model-dir outputs/dpo-model
